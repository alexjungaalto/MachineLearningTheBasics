# %%
print(__doc__)

# Author: Phil Roth <mr.phil.roth@gmail.com>
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.figure(figsize=(12, 12))

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state)
 # class sklearn.cluster.KMeans(n_clusters=8, *, init='k-means++', n_init=10, 
#                              max_iter=300, tol=0.0001, precompute_distances='deprecated', 
  #                            verbose=0, random_state=None, copy_x=True, n_jobs='deprecated', 
   # algorithm='auto')[source]¶
# Incorrect number of clusters
kmeansobj = KMeans(n_clusters=2, random_state=random_state,max_iter=1)
y_pred = kmeansobj.fit_predict(X)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
mc = kmeansobj.cluster_centers_
plt.scatter(mc[:,0],mc[:,1],marker='x',s=400,c='r')
plt.title("first iteration")

# Anisotropicly distributed data
#transformation = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
#X_aniso = np.dot(X, transformation)
#y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_aniso)

kmeansobj = KMeans(n_clusters=2, init=mc,max_iter=1)
y_pred = kmeansobj.fit_predict(X)

plt.subplot(222)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
mc = kmeansobj.cluster_centers_
plt.scatter(mc[:,0],mc[:,1],marker='x',s=400,c='r')
plt.title("second iteration")


kmeansobj = KMeans(n_clusters=2, init=mc,max_iter=1)
y_pred = kmeansobj.fit_predict(X)

plt.subplot(223)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
mc = kmeansobj.cluster_centers_
plt.scatter(mc[:,0],mc[:,1],marker='x',s=400,c='r')
plt.title("third iteration")


kmeansobj = KMeans(n_clusters=2, init=mc,max_iter=1)
y_pred = kmeansobj.fit_predict(X)

plt.subplot(224)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
mc = kmeansobj.cluster_centers_
plt.scatter(mc[:,0],mc[:,1],marker='x',s=400,c='r')
plt.title("fourth iteration")
plt.savefig('EvolKmeans.eps', format='eps')
plt.show()
# Out:
# Automatically created module for IPython interactive environment
# /Users/alexanderjung/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:972: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# /Users/alexanderjung/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:972: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# /Users/alexanderjung/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py:972: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
